# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
c=int(input("Enter a number: "))
if a> b and a> c:
  print(a, "is the largest number")
elif b> a and b> c:
  print(b, "is the largest number")
else:
  print(c, "is the largest number")
# Out:
# Enter a number:  10
# Enter a number:  20
# Enter a number:  30
# 30 is the largest number

# %%
year = int(input("Enter a year: "))
if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# Enter a year:  2026
# 2026 is not a leap year

# %%
chae = input("Enter a character: ").lower()
if chae.isalpha():
    if chae in 'aeiou':
        print(f"{chae} is a vowel")
    else:
        print(f"{chae} is a consonant")
else:
    print(f"{chae} is not an alphabet")
# Out:
# Enter a character:  2
# 2 is not an alphabet

# %%
n = int(input("Enter a number: "))
if n%5==0 and n%11==0:
  print(n,"is divisible by 5 and 11")
else:
  print(n,"is not divisible by 5 and 11")
# Out:
# Enter a number:  55
# 55 is divisible by 5 and 11

# %%
n = int(input("Enter a number: "))
i = 1
while i <= 10:
  print(i, "*", n, "=",i * n)
  i+=1
# Out:
# Enter a number:  22
# 1 * 22 = 22
# 2 * 22 = 44
# 3 * 22 = 66
# 4 * 22 = 88
# 5 * 22 = 110
# 6 * 22 = 132
# 7 * 22 = 154
# 8 * 22 = 176
# 9 * 22 = 198
# 10 * 22 = 220

# %%
n = int(input("Enter a number: "))
i = 1
sum = 0
while i <= n:
    sum += i
    i += 1
print("Sum of first", n, "natural numbers is:", sum)
# Out:
# Enter a number:  10
# Sum of first 10 natural numbers is: 55

# %%
n = int(input("Enter a number: "))
for i in range(n):
    print(' '*(n-i-1) + '*'*(2*i+1))
# Out:
# Enter a number:  5
#     *
#    ***
#   *****
#  *******
# *********

# %%
n = int(input("Enter a number: "))
for i in range(1, n+1):
    for j in range(1, i+1):
        print(j, end='')
    print()
# Out:
# Enter a number:  20
# 1
# 12
# 123
# 1234
# 12345
# 123456
# 1234567
# 12345678
# 123456789
# 12345678910
# 1234567891011
# 123456789101112
# 12345678910111213
# 1234567891011121314
# 123456789101112131415
# 12345678910111213141516
# 1234567891011121314151617
# 123456789101112131415161718
# 12345678910111213141516171819
# 1234567891011121314151617181920
