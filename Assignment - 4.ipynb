# %%
import pandas as pd

# %%
data = pd.read_csv("bmw.csv")
data.head(10)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# 5   5 Series  2016  14900    Automatic    35309   Diesel  125  60.1
# 6   5 Series  2017  16000    Automatic    38538   Diesel  125  60.1
# 7   2 Series  2018  16250       Manual    10401   Petrol  145  52.3
# 8   4 Series  2017  14250       Manual    42668   Diesel   30  62.8
# 9   5 Series  2016  14250    Automatic    36099   Diesel   20  68.9
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0
# 5         2.0
# 6         2.0
# 7         1.5
# 8         2.0
# 9         2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 631.8+ KB

# %%
data.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
data1 = pd.read_csv("dirty_cafe_sales.csv")
data1.head(10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0       ERROR
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211   UNKNOWN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867       NaN        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# ...

# %%
data1.isna().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
data1.dropna()
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data1
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data_min = data1.iloc[::20]

# %%
data_min
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data1[data1.isna().any(axis=1)]
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 5       TXN_2602893  Smoothie        5            4.0        20.0
# 8       TXN_4717867       NaN        5            3.0        15.0
# 9       TXN_2064365  Sandwich        5            4.0        20.0
# 13      TXN_9437049    Cookie        5            1.0         5.0
# 14      TXN_8915701     ERROR        2            1.5         3.0
# ...             ...       ...      ...            ...         ...
# 9994    TXN_7851634   UNKNOWN        4            4.0        16.0
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
#
#       Payment Method  Location Transaction Date
# 5        Credit Card       NaN       2023-03-31
# 8                NaN  Takeaway       2023-07-28
# ...

# %%
data_min = data1.iloc[::50]
data_min
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 50      TXN_7742742      Cake        5            3.0        15.0
# 100     TXN_9517146       NaN        5            5.0        25.0
# 150     TXN_8687151     Salad        5            5.0        25.0
# 200     TXN_2950680    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9750    TXN_5604021  Sandwich  UNKNOWN            4.0         4.0
# 9800    TXN_2954833    Coffee        1            2.0         2.0
# 9850    TXN_2562041      Cake        5            3.0        15.0
# 9900    TXN_5967452     Juice        5            3.0        15.0
# 9950    TXN_2818204      Cake        1            3.0         3.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 50               NaN  Takeaway       2023-09-05
# ...

# %%
data_min.fillna(500, inplace = True)
data_min
# Out:
# <ipython-input-21-4971d1c77621>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_min.fillna(500, inplace = True)
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 50      TXN_7742742      Cake        5            3.0        15.0
# 100     TXN_9517146       500        5            5.0        25.0
# 150     TXN_8687151     Salad        5            5.0        25.0
# 200     TXN_2950680    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9750    TXN_5604021  Sandwich  UNKNOWN            4.0         4.0
# 9800    TXN_2954833    Coffee        1            2.0         2.0
# 9850    TXN_2562041      Cake        5            3.0        15.0
# ...
